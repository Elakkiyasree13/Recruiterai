# %% [markdown]
# <a href="https://colab.research.google.com/github/Elakkiyasree13/Recruiterai/blob/main/fds1ques.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = {
    "Gender": ["Male","Female","Female","Male","Male","Female","Male","Female","Male","Female"],
    "Study_Hours": [2,5,3,6,4,7,1,8,5,6],
    "Attendance": [60,85,75,90,80,95,50,98,88,92],
    "Marks": [50,80,65,88,70,95,40,98,85,90]
}

df = pd.DataFrame(data)
df
# Out:
#    Gender  Study_Hours  Attendance  Marks
# 0    Male            2          60     50
# 1  Female            5          85     80
# 2  Female            3          75     65
# 3    Male            6          90     88
# 4    Male            4          80     70
# 5  Female            7          95     95
# 6    Male            1          50     40
# 7  Female            8          98     98
# 8    Male            5          88     85
# 9  Female            6          92     90

# %%
print("Problem: Analyze how Study Hours and Attendance affect Student Marks.")
# Out:
# Problem: Analyze how Study Hours and Attendance affect Student Marks.

# %%
# Check missing values
print(df.isnull().sum())

# Convert categorical to numeric
df["Gender"] = df["Gender"].map({"Male":0, "Female":1})

df
# Out:
# Gender         0
# Study_Hours    0
# Attendance     0
# Marks          0
# dtype: int64
#    Gender  Study_Hours  Attendance  Marks
# 0       0            2          60     50
# 1       1            5          85     80
# 2       1            3          75     65
# 3       0            6          90     88
# 4       0            4          80     70
# 5       1            7          95     95
# 6       0            1          50     40
# 7       1            8          98     98
# 8       0            5          88     85
# 9       1            6          92     90

# %%
sns.scatterplot(x="Study_Hours", y="Marks", data=df)
plt.title("Study Hours vs Marks")
plt.show()

sns.scatterplot(x="Attendance", y="Marks", data=df)
plt.title("Attendance vs Marks")
plt.show()

# %%
from sklearn.linear_model import LinearRegression

X = df[["Study_Hours", "Attendance"]]
y = df["Marks"]

model = LinearRegression()
model.fit(X, y)

print("Model Coefficients:", model.coef_)
# Out:
# Model Coefficients: [2.82332842 0.8529217 ]

# %%
pred = model.predict([[5, 85]])
print("Predicted Marks:", pred)
# Out:
# Predicted Marks: [80.1028088]
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
print("Conclusion: More study hours and attendance lead to higher marks.")
# Out:
# Conclusion: More study hours and attendance lead to higher marks.
